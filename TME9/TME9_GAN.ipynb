# %% [markdown]
# # <center>M2 DAC -   Reinforcement Learning & Advanced Deep</center>
# ##  <center> TME 9. Generative Adversarial Networks  </center>
#
# Ce TME a pour objectif d'expérimenter les Generative Adversarial Networks (GANs) sur un problème de génération de visages.
#
# De manière classique, un GAN se formule selon un problème adverse de la manière suivante:
# $$\min\limits_{G} \max\limits_D V(D,G) = \mathbb{E}_{x\sim p_{data}(x)}\big[logD(x)\big] + \mathbb{E}_{z\sim p_{z}(z)}\big[log(1-D(G(z)))\big]$$
# Cette formulation met en jeu deux réseaux adverse:
# *   Un réseau discriminateur $D$, dont l'objectif est de savoir distinguer les données réelles des données simulées
# *   Un réseau générateur $G$, dont l'objectif est de flouer le discriminateur
#
# À l'optimum, avec des réseaux de capacité infinie, la distribution $p_G$ des données générées par $G$ est prouvée suivre la distribution des données réelles $p_{data}$. Bien sûr nous ne travaillons pas avec des réseaux de capacité infinie (et d'ailleurs heureusement car on ne veut pas apprendre par coeur les données d'apprentissage), mais l'objectif est d'approcher cette distribution $p_{data}$ en apprenant un générateur neuronal dont les sorties sont difficilement distinguables des vraies données pour le discriminateur.
#
# Nous proposons de mettre ce genre d'architecture pour un la génération de visages: selon un ensemble de visages d'entraînement, il s'agit d'apprendre à générer des visages qui paraissent les plus réalistes possibles tout en conservant une certaine diversité dans les distributions de sortie. Pour cela nous emploierons une architecture DCGAN, qui utilise des réseaux de neurones convolutionnels (CNNs) pour le générateur et le discriminateur.

# %% [markdown]
# Pour ce TP, nous vous proposons de travailler avec Google Colab qui est un service notebook en ligne avec ressources machines à disposition (nécessite d'être connecté à un compte google personnel):
# *   https://colab.research.google.com/
# *   Ouvrir ce Notebook avec "File>Upload Notebook"
# *   Sélectionner un Runtime GPU : Runtime>Change Runtime Type (utile de le faire avant tout téléchargement de données car le changement de Runtime efface les données temporaires de la session)
#
# Pour télécharger les données utiles au TP:
#
#
# *   Aller à l'adresse : https://drive.google.com/open?id=0B7EVK8r0v71pWEZsZE9oNnFzTm8
# *   Clic-droit sur CelebA, Ajouter à mon Drive
# *   Exécuter le code ci-dessous (une autorisation vous sera demandée, suivre le lien donné à l'exécution pour obtenir le code d'authentification)
#
# (Sinon vous pouvez aussi travailler en local en téléchargeant les données sur votre ordinateur mais attention fichier volumineux et colab propose des ressources GPU utiles à la résolution du TP)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Vous devez maintenant avoir dans le paneau de gauche un onglet Files contenant un répertoire drive dans l'arborescence. C'est votre espace de stockage Google Drive. Il devrait contenir un répertoire CelebA (si ce n'est pas le cas attendre un peu et rafraichir, il peut mettre un certain temps à apparaître).
#
# Il s'agit maintenant de décompresser l'archive téléchargée (cela peut prendre jusqu'à une dizaine de minutes):

# %%
# !unzip drive/MyDrive/CelebA/Img/img_align_celeba -d data
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: data/img_align_celeba/197600.jpg
#   inflating: data/img_align_celeba/197601.jpg
#   inflating: data/img_align_celeba/197602.jpg
#   inflating: data/img_align_celeba/197603.jpg
#   inflating: data/img_align_celeba/197604.jpg
#   inflating: data/img_align_celeba/197605.jpg
#   inflating: data/img_align_celeba/197606.jpg
#   inflating: data/img_align_celeba/197607.jpg
#   inflating: data/img_align_celeba/197608.jpg
#   inflating: data/img_align_celeba/197609.jpg
#   inflating: data/img_align_celeba/197610.jpg
#   inflating: data/img_align_celeba/197611.jpg
#   inflating: data/img_align_celeba/197612.jpg
#   inflating: data/img_align_celeba/197613.jpg
#   inflating: data/img_align_celeba/197614.jpg
#   inflating: data/img_align_celeba/197615.jpg
#   inflating: data/img_align_celeba/197616.jpg
#   inflating: data/img_align_celeba/197617.jpg
#   inflating: data/img_align_celeba/197618.jpg
#   inflating: data/img_align_celeba/197619.jpg
#   inflating: data/img_align_celeba/197620.jpg
#   inflating: data/img_align_celeba/197621.jpg
#   inflating: data/img_align_celeba/197622.jpg
#   inflating: data/img_align_celeba/197623.jpg
#   inflating: data/img_align_celeba/197624.jpg
#   inflating: data/img_align_celeba/197625.jpg
#   inflating: data/img_align_celeba/197626.jpg
#   inflating: data/img_align_celeba/197627.jpg
#   inflating: data/img_align_celeba/197628.jpg
#   inflating: data/img_align_celeba/197629.jpg
#   inflating: data/img_align_celeba/197630.jpg
#   inflating: data/img_align_celeba/197631.jpg
#   inflating: data/img_align_celeba/197632.jpg
#   inflating: data/img_align_celeba/197633.jpg
#   inflating: data/img_align_celeba/197634.jpg
#   inflating: data/img_align_celeba/197635.jpg
#   inflating: data/img_align_celeba/197636.jpg
#   inflating: data/img_align_celeba/197637.jpg
#   inflating: data/img_align_celeba/197638.jpg
#   inflating: data/img_align_celeba/197639.jpg
#   inflating: data/img_align_celeba/197640.jpg
#   inflating: data/img_align_celeba/197641.jpg
#   inflating: data/img_align_celeba/197642.jpg
#   inflating: data/img_align_celeba/197643.jpg
#   inflating: data/img_align_celeba/197644.jpg
#   inflating: data/img_align_celeba/197645.jpg
#   inflating: data/img_align_celeba/197646.jpg
#   inflating: data/img_align_celeba/197647.jpg
#   inflating: data/img_align_celeba/197648.jpg
#   inflating: data/img_align_celeba/197649.jpg
#   inflating: data/img_align_celeba/197650.jpg
#   inflating: data/img_align_celeba/197651.jpg
#   inflating: data/img_align_celeba/197652.jpg
#   inflating: data/img_align_celeba/197653.jpg
#   inflating: data/img_align_celeba/197654.jpg
#   inflating: data/img_align_celeba/197655.jpg
#   inflating: data/img_align_celeba/197656.jpg
#   inflating: data/img_align_celeba/197657.jpg
#   inflating: data/img_align_celeba/197658.jpg
#   inflating: data/img_align_celeba/197659.jpg
#   inflating: data/img_align_celeba/197660.jpg
#   inflating: data/img_align_celeba/197661.jpg
#   inflating: data/img_align_celeba/197662.jpg
#   inflating: data/img_align_celeba/197663.jpg
#   inflating: data/img_align_celeba/197664.jpg
#   inflating: data/img_align_celeba/197665.jpg
#   inflating: data/img_align_celeba/197666.jpg
#   inflating: data/img_align_celeba/197667.jpg
#   inflating: data/img_align_celeba/197668.jpg
#   inflating: data/img_align_celeba/197669.jpg
#   inflating: data/img_align_celeba/197670.jpg
#   inflating: data/img_align_celeba/197671.jpg
#   inflating: data/img_align_celeba/197672.jpg
#   inflating: data/img_align_celeba/197673.jpg
#   inflating: data/img_align_celeba/197674.jpg
#   inflating: data/img_align_celeba/197675.jpg
#   inflating: data/img_align_celeba/197676.jpg
#   inflating: data/img_align_celeba/197677.jpg
#   inflating: data/img_align_celeba/197678.jpg
#   inflating: data/img_align_celeba/197679.jpg
#   inflating: data/img_align_celeba/197680.jpg
#   inflating: data/img_align_celeba/197681.jpg
#   inflating: data/img_align_celeba/197682.jpg
#   inflating: data/img_align_celeba/197683.jpg
#   inflating: data/img_align_celeba/197684.jpg
#   inflating: data/img_align_celeba/197685.jpg
#   inflating: data/img_align_celeba/197686.jpg
#   inflating: data/img_align_celeba/197687.jpg
#   inflating: data/img_align_celeba/197688.jpg
#   inflating: data/img_align_celeba/197689.jpg
#   inflating: data/img_align_celeba/197690.jpg
#   inflating: data/img_align_celeba/197691.jpg
#   inflating: data/img_align_celeba/197692.jpg
#   inflating: data/img_align_celeba/197693.jpg
#   inflating: data/img_align_celeba/197694.jpg
#   inflating: data/img_align_celeba/197695.jpg
#   inflating: data/img_align_celeba/197696.jpg
#   inflating: data/img_align_celeba/197697.jpg
#   inflating: data/img_align_celeba/197698.jpg
#   inflating: data/img_align_celeba/197699.jpg
#   inflating: data/img_align_celeba/197700.jpg
#   inflating: data/img_align_celeba/197701.jpg
#   inflating: data/img_align_celeba/197702.jpg
#   inflating: data/img_align_celeba/197703.jpg
#   inflating: data/img_align_celeba/197704.jpg
#   inflating: data/img_align_celeba/197705.jpg
#   inflating: data/img_align_celeba/197706.jpg
#   inflating: data/img_align_celeba/197707.jpg
#   inflating: data/img_align_celeba/197708.jpg
#   inflating: data/img_align_celeba/197709.jpg
#   inflating: data/img_align_celeba/197710.jpg
#   inflating: data/img_align_celeba/197711.jpg
#   inflating: data/img_align_celeba/197712.jpg
#   inflating: data/img_align_celeba/197713.jpg
#   inflating: data/img_align_celeba/197714.jpg
#   inflating: data/img_align_celeba/197715.jpg
#   inflating: data/img_align_celeba/197716.jpg
#   inflating: data/img_align_celeba/197717.jpg
#   inflating: data/img_align_celeba/197718.jpg
#   inflating: data/img_align_celeba/197719.jpg
#   inflating: data/img_align_celeba/197720.jpg
#   inflating: data/img_align_celeba/197721.jpg
#   inflating: data/img_align_celeba/197722.jpg
#   inflating: data/img_align_celeba/197723.jpg
#   inflating: data/img_align_celeba/197724.jpg
#   inflating: data/img_align_celeba/197725.jpg
#   inflating: data/img_align_celeba/197726.jpg
#   inflating: data/img_align_celeba/197727.jpg
#   inflating: data/img_align_celeba/197728.jpg
#   inflating: data/img_align_celeba/197729.jpg
#   inflating: data/img_align_celeba/197730.jpg
#   inflating: data/img_align_celeba/197731.jpg
#   inflating: data/img_align_celeba/197732.jpg
#   inflating: data/img_align_celeba/197733.jpg
#   inflating: data/img_align_celeba/197734.jpg
#   inflating: data/img_align_celeba/197735.jpg
#   inflating: data/img_align_celeba/197736.jpg
#   inflating: data/img_align_celeba/197737.jpg
#   inflating: data/img_align_celeba/197738.jpg
#   inflating: data/img_align_celeba/197739.jpg
#   inflating: data/img_align_celeba/197740.jpg
#   inflating: data/img_align_celeba/197741.jpg
#   inflating: data/img_align_celeba/197742.jpg
#   inflating: data/img_align_celeba/197743.jpg
#   inflating: data/img_align_celeba/197744.jpg
#   inflating: data/img_align_celeba/197745.jpg
#   inflating: data/img_align_celeba/197746.jpg
#   inflating: data/img_align_celeba/197747.jpg
#   inflating: data/img_align_celeba/197748.jpg
#   inflating: data/img_align_celeba/197749.jpg
#   inflating: data/img_align_celeba/197750.jpg
#   inflating: data/img_align_celeba/197751.jpg
#   inflating: data/img_align_celeba/197752.jpg
#   inflating: data/img_align_celeba/197753.jpg
#   inflating: data/img_align_celeba/197754.jpg
#   inflating: data/img_align_celeba/197755.jpg
#   inflating: data/img_align_celeba/197756.jpg
#   inflating: data/img_align_celeba/197757.jpg
#   inflating: data/img_align_celeba/197758.jpg
#   inflating: data/img_align_celeba/197759.jpg
#   inflating: data/img_align_celeba/197760.jpg
#   inflating: data/img_align_celeba/197761.jpg
#   inflating: data/img_align_celeba/197762.jpg
#   inflating: data/img_align_celeba/197763.jpg
#   inflating: data/img_align_celeba/197764.jpg
#   inflating: data/img_align_celeba/197765.jpg
#   inflating: data/img_align_celeba/197766.jpg
#   inflating: data/img_align_celeba/197767.jpg
#   inflating: data/img_align_celeba/197768.jpg
#   inflating: data/img_align_celeba/197769.jpg
#   inflating: data/img_align_celeba/197770.jpg
#   inflating: data/img_align_celeba/197771.jpg
#   inflating: data/img_align_celeba/197772.jpg
#   inflating: data/img_align_celeba/197773.jpg
#   inflating: data/img_align_celeba/197774.jpg
#   inflating: data/img_align_celeba/197775.jpg
#   inflating: data/img_align_celeba/197776.jpg
#   inflating: data/img_align_celeba/197777.jpg
#   inflating: data/img_align_celeba/197778.jpg
#   inflating: data/img_align_celeba/197779.jpg
#   inflating: data/img_align_celeba/197780.jpg
#   inflating: data/img_align_celeba/197781.jpg
#   inflating: data/img_align_celeba/197782.jpg
#   inflating: data/img_align_celeba/197783.jpg
#   inflating: data/img_align_celeba/197784.jpg
#   inflating: data/img_align_celeba/197785.jpg
#   inflating: data/img_align_celeba/197786.jpg
#   inflating: data/img_align_celeba/197787.jpg
#   inflating: data/img_align_celeba/197788.jpg
#   inflating: data/img_align_celeba/197789.jpg
#   inflating: data/img_align_celeba/197790.jpg
#   inflating: data/img_align_celeba/197791.jpg
#   inflating: data/img_align_celeba/197792.jpg
#   inflating: data/img_align_celeba/197793.jpg
#   inflating: data/img_align_celeba/197794.jpg
#   inflating: data/img_align_celeba/197795.jpg
#   inflating: data/img_align_celeba/197796.jpg
#   inflating: data/img_align_celeba/197797.jpg
#   inflating: data/img_align_celeba/197798.jpg
#   inflating: data/img_align_celeba/197799.jpg
#   inflating: data/img_align_celeba/197800.jpg
#   inflating: data/img_align_celeba/197801.jpg
#   inflating: data/img_align_celeba/197802.jpg
#   inflating: data/img_align_celeba/197803.jpg
#   inflating: data/img_align_celeba/197804.jpg
#   inflating: data/img_align_celeba/197805.jpg
#   inflating: data/img_align_celeba/197806.jpg
#   inflating: data/img_align_celeba/197807.jpg
#   inflating: data/img_align_celeba/197808.jpg
#   inflating: data/img_align_celeba/197809.jpg
#   inflating: data/img_align_celeba/197810.jpg
#   inflating: data/img_align_celeba/197811.jpg
#   inflating: data/img_align_celeba/197812.jpg
#   inflating: data/img_align_celeba/197813.jpg
#   inflating: data/img_align_celeba/197814.jpg
#   inflating: data/img_align_celeba/197815.jpg
#   inflating: data/img_align_celeba/197816.jpg
#   inflating: data/img_align_celeba/197817.jpg
#   inflating: data/img_align_celeba/197818.jpg
#   inflating: data/img_align_celeba/197819.jpg
#   inflating: data/img_align_celeba/197820.jpg
#   inflating: data/img_align_celeba/197821.jpg
#   inflating: data/img_align_celeba/197822.jpg
#   inflating: data/img_align_celeba/197823.jpg
#   inflating: data/img_align_celeba/197824.jpg
#   inflating: data/img_align_celeba/197825.jpg
#   inflating: data/img_align_celeba/197826.jpg
#   inflating: data/img_align_celeba/197827.jpg
#   inflating: data/img_align_celeba/197828.jpg
#   inflating: data/img_align_celeba/197829.jpg
#   inflating: data/img_align_celeba/197830.jpg
#   inflating: data/img_align_celeba/197831.jpg
#   inflating: data/img_align_celeba/197832.jpg
#   inflating: data/img_align_celeba/197833.jpg
#   inflating: data/img_align_celeba/197834.jpg
#   inflating: data/img_align_celeba/197835.jpg
#   inflating: data/img_align_celeba/197836.jpg
#   inflating: data/img_align_celeba/197837.jpg
#   inflating: data/img_align_celeba/197838.jpg
#   inflating: data/img_align_celeba/197839.jpg
#   inflating: data/img_align_celeba/197840.jpg
#   inflating: data/img_align_celeba/197841.jpg
#   inflating: data/img_align_celeba/197842.jpg
#   inflating: data/img_align_celeba/197843.jpg
#   inflating: data/img_align_celeba/197844.jpg
#   inflating: data/img_align_celeba/197845.jpg
#   inflating: data/img_align_celeba/197846.jpg
#   inflating: data/img_align_celeba/197847.jpg
#   inflating: data/img_align_celeba/197848.jpg
#   inflating: data/img_align_celeba/197849.jpg
#   inflating: data/img_align_celeba/197850.jpg
#   inflating: data/img_align_celeba/197851.jpg
#   inflating: data/img_align_celeba/197852.jpg
#   inflating: data/img_align_celeba/197853.jpg
#   inflating: data/img_align_celeba/197854.jpg
#   inflating: data/img_align_celeba/197855.jpg
#   inflating: data/img_align_celeba/197856.jpg
#   inflating: data/img_align_celeba/197857.jpg
#   inflating: data/img_align_celeba/197858.jpg
#   inflating: data/img_align_celeba/197859.jpg
#   inflating: data/img_align_celeba/197860.jpg
#   inflating: data/img_align_celeba/197861.jpg
#   inflating: data/img_align_celeba/197862.jpg
#   inflating: data/img_align_celeba/197863.jpg
#   inflating: data/img_align_celeba/197864.jpg
#   inflating: data/img_align_celeba/197865.jpg
#   inflating: data/img_align_celeba/197866.jpg
#   inflating: data/img_align_celeba/197867.jpg
#   inflating: data/img_align_celeba/197868.jpg
#   inflating: data/img_align_celeba/197869.jpg
#   inflating: data/img_align_celeba/197870.jpg
#   inflating: data/img_align_celeba/197871.jpg
#   inflating: data/img_align_celeba/197872.jpg
#   inflating: data/img_align_celeba/197873.jpg
#   inflating: data/img_align_celeba/197874.jpg
#   inflating: data/img_align_celeba/197875.jpg
#   inflating: data/img_align_celeba/197876.jpg
#   inflating: data/img_align_celeba/197877.jpg
#   inflating: data/img_align_celeba/197878.jpg
#   inflating: data/img_align_celeba/197879.jpg
#   inflating: data/img_align_celeba/197880.jpg
#   inflating: data/img_align_celeba/197881.jpg
#   inflating: data/img_align_celeba/197882.jpg
#   inflating: data/img_align_celeba/197883.jpg
#   inflating: data/img_align_celeba/197884.jpg
#   inflating: data/img_align_celeba/197885.jpg
#   inflating: data/img_align_celeba/197886.jpg
#   inflating: data/img_align_celeba/197887.jpg
#   inflating: data/img_align_celeba/197888.jpg
#   inflating: data/img_align_celeba/197889.jpg
#   inflating: data/img_align_celeba/197890.jpg
#   inflating: data/img_align_celeba/197891.jpg
#   inflating: data/img_align_celeba/197892.jpg
#   inflating: data/img_align_celeba/197893.jpg
#   inflating: data/img_align_celeba/197894.jpg
#   inflating: data/img_align_celeba/197895.jpg
#   inflating: data/img_align_celeba/197896.jpg
#   inflating: data/img_align_celeba/197897.jpg
#   inflating: data/img_align_celeba/197898.jpg
#   inflating: data/img_align_celeba/197899.jpg
#   inflating: data/img_align_celeba/197900.jpg
#   inflating: data/img_align_celeba/197901.jpg
#   inflating: data/img_align_celeba/197902.jpg
#   inflating: data/img_align_celeba/197903.jpg
#   inflating: data/img_align_celeba/197904.jpg
#   inflating: data/img_align_celeba/197905.jpg
#   inflating: data/img_align_celeba/197906.jpg
#   inflating: data/img_align_celeba/197907.jpg
#   inflating: data/img_align_celeba/197908.jpg
#   inflating: data/img_align_celeba/197909.jpg
#   inflating: data/img_align_celeba/197910.jpg
#   inflating: data/img_align_celeba/197911.jpg
#   inflating: data/img_align_celeba/197912.jpg
#   inflating: data/img_align_celeba/197913.jpg
#   inflating: data/img_align_celeba/197914.jpg
#   inflating: data/img_align_celeba/197915.jpg
#   inflating: data/img_align_celeba/197916.jpg
#   inflating: data/img_align_celeba/197917.jpg
#   inflating: data/img_align_celeba/197918.jpg
#   inflating: data/img_align_celeba/197919.jpg
#   inflating: data/img_align_celeba/197920.jpg
#   inflating: data/img_align_celeba/197921.jpg
#   inflating: data/img_align_celeba/197922.jpg
#   inflating: data/img_align_celeba/197923.jpg
#   inflating: data/img_align_celeba/197924.jpg
#   inflating: data/img_align_celeba/197925.jpg
#   inflating: data/img_align_celeba/197926.jpg
#   inflating: data/img_align_celeba/197927.jpg
#   inflating: data/img_align_celeba/197928.jpg
#   inflating: data/img_align_celeba/197929.jpg
#   inflating: data/img_align_celeba/197930.jpg
#   inflating: data/img_align_celeba/197931.jpg
#   inflating: data/img_align_celeba/197932.jpg
#   inflating: data/img_align_celeba/197933.jpg
#   inflating: data/img_align_celeba/197934.jpg
#   inflating: data/img_align_celeba/197935.jpg
#   inflating: data/img_align_celeba/197936.jpg
#   inflating: data/img_align_celeba/197937.jpg
#   inflating: data/img_align_celeba/197938.jpg
#   inflating: data/img_align_celeba/197939.jpg
#   inflating: data/img_align_celeba/197940.jpg
#   inflating: data/img_align_celeba/197941.jpg
#   inflating: data/img_align_celeba/197942.jpg
#   inflating: data/img_align_celeba/197943.jpg
#   inflating: data/img_align_celeba/197944.jpg
#   inflating: data/img_align_celeba/197945.jpg
#   inflating: data/img_align_celeba/197946.jpg
#   inflating: data/img_align_celeba/197947.jpg
#   inflating: data/img_align_celeba/197948.jpg
#   inflating: data/img_align_celeba/197949.jpg
#   inflating: data/img_align_celeba/197950.jpg
#   inflating: data/img_align_celeba/197951.jpg
#   inflating: data/img_align_celeba/197952.jpg
#   inflating: data/img_align_celeba/197953.jpg
#   inflating: data/img_align_celeba/197954.jpg
#   inflating: data/img_align_celeba/197955.jpg
#   inflating: data/img_align_celeba/197956.jpg
#   inflating: data/img_align_celeba/197957.jpg
#   inflating: data/img_align_celeba/197958.jpg
#   inflating: data/img_align_celeba/197959.jpg
#   inflating: data/img_align_celeba/197960.jpg
#   inflating: data/img_align_celeba/197961.jpg
#   inflating: data/img_align_celeba/197962.jpg
#   inflating: data/img_align_celeba/197963.jpg
#   inflating: data/img_align_celeba/197964.jpg
#   inflating: data/img_align_celeba/197965.jpg
#   inflating: data/img_align_celeba/197966.jpg
#   inflating: data/img_align_celeba/197967.jpg
#   inflating: data/img_align_celeba/197968.jpg
#   inflating: data/img_align_celeba/197969.jpg
#   inflating: data/img_align_celeba/197970.jpg
#   inflating: data/img_align_celeba/197971.jpg
#   inflating: data/img_align_celeba/197972.jpg
#   inflating: data/img_align_celeba/197973.jpg
#   inflating: data/img_align_celeba/197974.jpg
#   inflating: data/img_align_celeba/197975.jpg
#   inflating: data/img_align_celeba/197976.jpg
#   inflating: data/img_align_celeba/197977.jpg
#   inflating: data/img_align_celeba/197978.jpg
#   inflating: data/img_align_celeba/197979.jpg
#   inflating: data/img_align_celeba/197980.jpg
#   inflating: data/img_align_celeba/197981.jpg
#   inflating: data/img_align_celeba/197982.jpg
#   inflating: data/img_align_celeba/197983.jpg
#   inflating: data/img_align_celeba/197984.jpg
#   inflating: data/img_align_celeba/197985.jpg
#   inflating: data/img_align_celeba/197986.jpg
#   inflating: data/img_align_celeba/197987.jpg
#   inflating: data/img_align_celeba/197988.jpg
#   inflating: data/img_align_celeba/197989.jpg
#   inflating: data/img_align_celeba/197990.jpg
#   inflating: data/img_align_celeba/197991.jpg
#   inflating: data/img_align_celeba/197992.jpg
#   inflating: data/img_align_celeba/197993.jpg
#   inflating: data/img_align_celeba/197994.jpg
#   inflating: data/img_align_celeba/197995.jpg
#   inflating: data/img_align_celeba/197996.jpg
#   inflating: data/img_align_celeba/197997.jpg
#   inflating: data/img_align_celeba/197998.jpg
#   inflating: data/img_align_celeba/197999.jpg
#   inflating: data/img_align_celeba/198000.jpg
#   inflating: data/img_align_celeba/198001.jpg
#   inflating: data/img_align_celeba/198002.jpg
#   inflating: data/img_align_celeba/198003.jpg
#   inflating: data/img_align_celeba/198004.jpg
#   inflating: data/img_align_celeba/198005.jpg
#   inflating: data/img_align_celeba/198006.jpg
#   inflating: data/img_align_celeba/198007.jpg
#   inflating: data/img_align_celeba/198008.jpg
#   inflating: data/img_align_celeba/198009.jpg
#   inflating: data/img_align_celeba/198010.jpg
#   inflating: data/img_align_celeba/198011.jpg
#   inflating: data/img_align_celeba/198012.jpg
#   inflating: data/img_align_celeba/198013.jpg
#   inflating: data/img_align_celeba/198014.jpg
#   inflating: data/img_align_celeba/198015.jpg
#   inflating: data/img_align_celeba/198016.jpg
#   inflating: data/img_align_celeba/198017.jpg
#   inflating: data/img_align_celeba/198018.jpg
#   inflating: data/img_align_celeba/198019.jpg
#   inflating: data/img_align_celeba/198020.jpg
#   inflating: data/img_align_celeba/198021.jpg
#   inflating: data/img_align_celeba/198022.jpg
#   inflating: data/img_align_celeba/198023.jpg
#   inflating: data/img_align_celeba/198024.jpg
#   inflating: data/img_align_celeba/198025.jpg
#   inflating: data/img_align_celeba/198026.jpg
#   inflating: data/img_align_celeba/198027.jpg
#   inflating: data/img_align_celeba/198028.jpg
#   inflating: data/img_align_celeba/198029.jpg
#   inflating: data/img_align_celeba/198030.jpg
#   inflating: data/img_align_celeba/198031.jpg
#   inflating: data/img_align_celeba/198032.jpg
#   inflating: data/img_align_celeba/198033.jpg
#   inflating: data/img_align_celeba/198034.jpg
#   inflating: data/img_align_celeba/198035.jpg
#   inflating: data/img_align_celeba/198036.jpg
#   inflating: data/img_align_celeba/198037.jpg
#   inflating: data/img_align_celeba/198038.jpg
#   inflating: data/img_align_celeba/198039.jpg
#   inflating: data/img_align_celeba/198040.jpg
#   inflating: data/img_align_celeba/198041.jpg
#   inflating: data/img_align_celeba/198042.jpg
#   inflating: data/img_align_celeba/198043.jpg
#   inflating: data/img_align_celeba/198044.jpg
#   inflating: data/img_align_celeba/198045.jpg
#   inflating: data/img_align_celeba/198046.jpg
#   inflating: data/img_align_celeba/198047.jpg
#   inflating: data/img_align_celeba/198048.jpg
#   inflating: data/img_align_celeba/198049.jpg
#   inflating: data/img_align_celeba/198050.jpg
#   inflating: data/img_align_celeba/198051.jpg
#   inflating: data/img_align_celeba/198052.jpg
#   inflating: data/img_align_celeba/198053.jpg
#   inflating: data/img_align_celeba/198054.jpg
#   inflating: data/img_align_celeba/198055.jpg
#   inflating: data/img_align_celeba/198056.jpg
#   inflating: data/img_align_celeba/198057.jpg
#   inflating: data/img_align_celeba/198058.jpg
#   inflating: data/img_align_celeba/198059.jpg
#   inflating: data/img_align_celeba/198060.jpg
#   inflating: data/img_align_celeba/198061.jpg
#   inflating: data/img_align_celeba/198062.jpg
#   inflating: data/img_align_celeba/198063.jpg
#   inflating: data/img_align_celeba/198064.jpg
#   inflating: data/img_align_celeba/198065.jpg
#   inflating: data/img_align_celeba/198066.jpg
#   inflating: data/img_align_celeba/198067.jpg
#   inflating: data/img_align_celeba/198068.jpg
#   inflating: data/img_align_celeba/198069.jpg
#   inflating: data/img_align_celeba/198070.jpg
#   inflating: data/img_align_celeba/198071.jpg
#   inflating: data/img_align_celeba/198072.jpg
#   inflating: data/img_align_celeba/198073.jpg
#   inflating: data/img_align_celeba/198074.jpg
#   inflating: data/img_align_celeba/198075.jpg
#   inflating: data/img_align_celeba/198076.jpg
#   inflating: data/img_align_celeba/198077.jpg
#   inflating: data/img_align_celeba/198078.jpg
#   inflating: data/img_align_celeba/198079.jpg
#   inflating: data/img_align_celeba/198080.jpg
#   inflating: data/img_align_celeba/198081.jpg
#   inflating: data/img_align_celeba/198082.jpg
#   inflating: data/img_align_celeba/198083.jpg
#   inflating: data/img_align_celeba/198084.jpg
#   inflating: data/img_align_celeba/198085.jpg
#   inflating: data/img_align_celeba/198086.jpg
#   inflating: data/img_align_celeba/198087.jpg
#   inflating: data/img_align_celeba/198088.jpg
#   inflating: data/img_align_celeba/198089.jpg
#   inflating: data/img_align_celeba/198090.jpg
#   inflating: data/img_align_celeba/198091.jpg
#   inflating: data/img_align_celeba/198092.jpg
#   inflating: data/img_align_celeba/198093.jpg
#   inflating: data/img_align_celeba/198094.jpg
#   inflating: data/img_align_celeba/198095.jpg
#   inflating: data/img_align_celeba/198096.jpg
#   inflating: data/img_align_celeba/198097.jpg
#   inflating: data/img_align_celeba/198098.jpg
#   inflating: data/img_align_celeba/198099.jpg
#   inflating: data/img_align_celeba/198100.jpg
#   inflating: data/img_align_celeba/198101.jpg
#   inflating: data/img_align_celeba/198102.jpg
#   inflating: data/img_align_celeba/198103.jpg
#   inflating: data/img_align_celeba/198104.jpg
#   inflating: data/img_align_celeba/198105.jpg
#   inflating: data/img_align_celeba/198106.jpg
#   inflating: data/img_align_celeba/198107.jpg
#   inflating: data/img_align_celeba/198108.jpg
#   inflating: data/img_align_celeba/198109.jpg
#   inflating: data/img_align_celeba/198110.jpg
#   inflating: data/img_align_celeba/198111.jpg
#   inflating: data/img_align_celeba/198112.jpg
#   inflating: data/img_align_celeba/198113.jpg
#   inflating: data/img_align_celeba/198114.jpg
#   inflating: data/img_align_celeba/198115.jpg
#   inflating: data/img_align_celeba/198116.jpg
#   inflating: data/img_align_celeba/198117.jpg
#   inflating: data/img_align_celeba/198118.jpg
#   inflating: data/img_align_celeba/198119.jpg
#   inflating: data/img_align_celeba/198120.jpg
#   inflating: data/img_align_celeba/198121.jpg
#   inflating: data/img_align_celeba/198122.jpg
#   inflating: data/img_align_celeba/198123.jpg
#   inflating: data/img_align_celeba/198124.jpg
#   inflating: data/img_align_celeba/198125.jpg
#   inflating: data/img_align_celeba/198126.jpg
#   inflating: data/img_align_celeba/198127.jpg
#   inflating: data/img_align_celeba/198128.jpg
#   inflating: data/img_align_celeba/198129.jpg
#   inflating: data/img_align_celeba/198130.jpg
#   inflating: data/img_align_celeba/198131.jpg
#   inflating: data/img_align_celeba/198132.jpg
#   inflating: data/img_align_celeba/198133.jpg
#   inflating: data/img_align_celeba/198134.jpg
#   inflating: data/img_align_celeba/198135.jpg
#   inflating: data/img_align_celeba/198136.jpg
#   inflating: data/img_align_celeba/198137.jpg
#   inflating: data/img_align_celeba/198138.jpg
#   inflating: data/img_align_celeba/198139.jpg
#   inflating: data/img_align_celeba/198140.jpg
#   inflating: data/img_align_celeba/198141.jpg
#   inflating: data/img_align_celeba/198142.jpg
#   inflating: data/img_align_celeba/198143.jpg
#   inflating: data/img_align_celeba/198144.jpg
#   inflating: data/img_align_celeba/198145.jpg
#   inflating: data/img_align_celeba/198146.jpg
#   inflating: data/img_align_celeba/198147.jpg
#   inflating: data/img_align_celeba/198148.jpg
#   inflating: data/img_align_celeba/198149.jpg
#   inflating: data/img_align_celeba/198150.jpg
#   inflating: data/img_align_celeba/198151.jpg
#   inflating: data/img_align_celeba/198152.jpg
#   inflating: data/img_align_celeba/198153.jpg
#   inflating: data/img_align_celeba/198154.jpg
#   inflating: data/img_align_celeba/198155.jpg
#   inflating: data/img_align_celeba/198156.jpg
#   inflating: data/img_align_celeba/198157.jpg
#   inflating: data/img_align_celeba/198158.jpg
#   inflating: data/img_align_celeba/198159.jpg
#   inflating: data/img_align_celeba/198160.jpg
#   inflating: data/img_align_celeba/198161.jpg
#   inflating: data/img_align_celeba/198162.jpg
#   inflating: data/img_align_celeba/198163.jpg
#   inflating: data/img_align_celeba/198164.jpg
#   inflating: data/img_align_celeba/198165.jpg
#   inflating: data/img_align_celeba/198166.jpg
#   inflating: data/img_align_celeba/198167.jpg
#   inflating: data/img_align_celeba/198168.jpg
#   inflating: data/img_align_celeba/198169.jpg
#   inflating: data/img_align_celeba/198170.jpg
#   inflating: data/img_align_celeba/198171.jpg
#   inflating: data/img_align_celeba/198172.jpg
#   inflating: data/img_align_celeba/198173.jpg
#   inflating: data/img_align_celeba/198174.jpg
#   inflating: data/img_align_celeba/198175.jpg
#   inflating: data/img_align_celeba/198176.jpg
#   inflating: data/img_align_celeba/198177.jpg
#   inflating: data/img_align_celeba/198178.jpg
#   inflating: data/img_align_celeba/198179.jpg
#   inflating: data/img_align_celeba/198180.jpg
#   inflating: data/img_align_celeba/198181.jpg
#   inflating: data/img_align_celeba/198182.jpg
#   inflating: data/img_align_celeba/198183.jpg
#   inflating: data/img_align_celeba/198184.jpg
#   inflating: data/img_align_celeba/198185.jpg
#   inflating: data/img_align_celeba/198186.jpg
#   inflating: data/img_align_celeba/198187.jpg
#   inflating: data/img_align_celeba/198188.jpg
#   inflating: data/img_align_celeba/198189.jpg
#   inflating: data/img_align_celeba/198190.jpg
#   inflating: data/img_align_celeba/198191.jpg
#   inflating: data/img_align_celeba/198192.jpg
#   inflating: data/img_align_celeba/198193.jpg
#   inflating: data/img_align_celeba/198194.jpg
#   inflating: data/img_align_celeba/198195.jpg
#   inflating: data/img_align_celeba/198196.jpg
#   inflating: data/img_align_celeba/198197.jpg
#   inflating: data/img_align_celeba/198198.jpg
#   inflating: data/img_align_celeba/198199.jpg
#   inflating: data/img_align_celeba/198200.jpg
#   inflating: data/img_align_celeba/198201.jpg
#   inflating: data/img_align_celeba/198202.jpg
#   inflating: data/img_align_celeba/198203.jpg
#   inflating: data/img_align_celeba/198204.jpg
#   inflating: data/img_align_celeba/198205.jpg
#   inflating: data/img_align_celeba/198206.jpg
#   inflating: data/img_align_celeba/198207.jpg
#   inflating: data/img_align_celeba/198208.jpg
#   inflating: data/img_align_celeba/198209.jpg
#   inflating: data/img_align_celeba/198210.jpg
#   inflating: data/img_align_celeba/198211.jpg
#   inflating: data/img_align_celeba/198212.jpg
#   inflating: data/img_align_celeba/198213.jpg
#   inflating: data/img_align_celeba/198214.jpg
#   inflating: data/img_align_celeba/198215.jpg
#   inflating: data/img_align_celeba/198216.jpg
#   inflating: data/img_align_celeba/198217.jpg
#   inflating: data/img_align_celeba/198218.jpg
#   inflating: data/img_align_celeba/198219.jpg
#   inflating: data/img_align_celeba/198220.jpg
#   inflating: data/img_align_celeba/198221.jpg
#   inflating: data/img_align_celeba/198222.jpg
#   inflating: data/img_align_celeba/198223.jpg
#   inflating: data/img_align_celeba/198224.jpg
#   inflating: data/img_align_celeba/198225.jpg
#   inflating: data/img_align_celeba/198226.jpg
#   inflating: data/img_align_celeba/198227.jpg
#   inflating: data/img_align_celeba/198228.jpg
#   inflating: data/img_align_celeba/198229.jpg
#   inflating: data/img_align_celeba/198230.jpg
#   inflating: data/img_align_celeba/198231.jpg
#   inflating: data/img_align_celeba/198232.jpg
#   inflating: data/img_align_celeba/198233.jpg
#   inflating: data/img_align_celeba/198234.jpg
#   inflating: data/img_align_celeba/198235.jpg
#   inflating: data/img_align_celeba/198236.jpg
#   inflating: data/img_align_celeba/198237.jpg
#   inflating: data/img_align_celeba/198238.jpg
#   inflating: data/img_align_celeba/198239.jpg
#   inflating: data/img_align_celeba/198240.jpg
#   inflating: data/img_align_celeba/198241.jpg
#   inflating: data/img_align_celeba/198242.jpg
#   inflating: data/img_align_celeba/198243.jpg
#   inflating: data/img_align_celeba/198244.jpg
#   inflating: data/img_align_celeba/198245.jpg
#   inflating: data/img_align_celeba/198246.jpg
#   inflating: data/img_align_celeba/198247.jpg
#   inflating: data/img_align_celeba/198248.jpg
#   inflating: data/img_align_celeba/198249.jpg
#   inflating: data/img_align_celeba/198250.jpg
#   inflating: data/img_align_celeba/198251.jpg
#   inflating: data/img_align_celeba/198252.jpg
#   inflating: data/img_align_celeba/198253.jpg
#   inflating: data/img_align_celeba/198254.jpg
#   inflating: data/img_align_celeba/198255.jpg
#   inflating: data/img_align_celeba/198256.jpg
#   inflating: data/img_align_celeba/198257.jpg
#   inflating: data/img_align_celeba/198258.jpg
#   inflating: data/img_align_celeba/198259.jpg
#   inflating: data/img_align_celeba/198260.jpg
#   inflating: data/img_align_celeba/198261.jpg
#   inflating: data/img_align_celeba/198262.jpg
#   inflating: data/img_align_celeba/198263.jpg
#   inflating: data/img_align_celeba/198264.jpg
#   inflating: data/img_align_celeba/198265.jpg
#   inflating: data/img_align_celeba/198266.jpg
#   inflating: data/img_align_celeba/198267.jpg
#   inflating: data/img_align_celeba/198268.jpg
#   inflating: data/img_align_celeba/198269.jpg
#   inflating: data/img_align_celeba/198270.jpg
#   inflating: data/img_align_celeba/198271.jpg
#   inflating: data/img_align_celeba/198272.jpg
#   inflating: data/img_align_celeba/198273.jpg
#   inflating: data/img_align_celeba/198274.jpg
#   inflating: data/img_align_celeba/198275.jpg
#   inflating: data/img_align_celeba/198276.jpg
#   inflating: data/img_align_celeba/198277.jpg
#   inflating: data/img_align_celeba/198278.jpg
#   inflating: data/img_align_celeba/198279.jpg
#   inflating: data/img_align_celeba/198280.jpg
#   inflating: data/img_align_celeba/198281.jpg
#   inflating: data/img_align_celeba/198282.jpg
#   inflating: data/img_align_celeba/198283.jpg
#   inflating: data/img_align_celeba/198284.jpg
#   inflating: data/img_align_celeba/198285.jpg
#   inflating: data/img_align_celeba/198286.jpg
#   inflating: data/img_align_celeba/198287.jpg
#   inflating: data/img_align_celeba/198288.jpg
#   inflating: data/img_align_celeba/198289.jpg
#   inflating: data/img_align_celeba/198290.jpg
#   inflating: data/img_align_celeba/198291.jpg
#   inflating: data/img_align_celeba/198292.jpg
#   inflating: data/img_align_celeba/198293.jpg
#   inflating: data/img_align_celeba/198294.jpg
#   inflating: data/img_align_celeba/198295.jpg
#   inflating: data/img_align_celeba/198296.jpg
#   inflating: data/img_align_celeba/198297.jpg
#   inflating: data/img_align_celeba/198298.jpg
#   inflating: data/img_align_celeba/198299.jpg
#   inflating: data/img_align_celeba/198300.jpg
#   inflating: data/img_align_celeba/198301.jpg
#   inflating: data/img_align_celeba/198302.jpg
#   inflating: data/img_align_celeba/198303.jpg
#   inflating: data/img_align_celeba/198304.jpg
#   inflating: data/img_align_celeba/198305.jpg
#   inflating: data/img_align_celeba/198306.jpg
#   inflating: data/img_align_celeba/198307.jpg
#   inflating: data/img_align_celeba/198308.jpg
#   inflating: data/img_align_celeba/198309.jpg
#   inflating: data/img_align_celeba/198310.jpg
#   inflating: data/img_align_celeba/198311.jpg
#   inflating: data/img_align_celeba/198312.jpg
#   inflating: data/img_align_celeba/198313.jpg
#   inflating: data/img_align_celeba/198314.jpg
#   inflating: data/img_align_celeba/198315.jpg
#   inflating: data/img_align_celeba/198316.jpg
#   inflating: data/img_align_celeba/198317.jpg
#   inflating: data/img_align_celeba/198318.jpg
#   inflating: data/img_align_celeba/198319.jpg
#   inflating: data/img_align_celeba/198320.jpg
#   inflating: data/img_align_celeba/198321.jpg
#   inflating: data/img_align_celeba/198322.jpg
#   inflating: data/img_align_celeba/198323.jpg
#   inflating: data/img_align_celeba/198324.jpg
#   inflating: data/img_align_celeba/198325.jpg
#   inflating: data/img_align_celeba/198326.jpg
#   inflating: data/img_align_celeba/198327.jpg
#   inflating: data/img_align_celeba/198328.jpg
#   inflating: data/img_align_celeba/198329.jpg
#   inflating: data/img_align_celeba/198330.jpg
#   inflating: data/img_align_celeba/198331.jpg
#   inflating: data/img_align_celeba/198332.jpg
#   inflating: data/img_align_celeba/198333.jpg
#   inflating: data/img_align_celeba/198334.jpg
#   inflating: data/img_align_celeba/198335.jpg
#   inflating: data/img_align_celeba/198336.jpg
#   inflating: data/img_align_celeba/198337.jpg
#   inflating: data/img_align_celeba/198338.jpg
#   inflating: data/img_align_celeba/198339.jpg
#   inflating: data/img_align_celeba/198340.jpg
#   inflating: data/img_align_celeba/198341.jpg
#   inflating: data/img_align_celeba/198342.jpg
#   inflating: data/img_align_celeba/198343.jpg
#   inflating: data/img_align_celeba/198344.jpg
#   inflating: data/img_align_celeba/198345.jpg
#   inflating: data/img_align_celeba/198346.jpg
#   inflating: data/img_align_celeba/198347.jpg
#   inflating: data/img_align_celeba/198348.jpg
#   inflating: data/img_align_celeba/198349.jpg
#   inflating: data/img_align_celeba/198350.jpg
#   inflating: data/img_align_celeba/198351.jpg
#   inflating: data/img_align_celeba/198352.jpg
#   inflating: data/img_align_celeba/198353.jpg
#   inflating: data/img_align_celeba/198354.jpg
#   inflating: data/img_align_celeba/198355.jpg
#   inflating: data/img_align_celeba/198356.jpg
#   inflating: data/img_align_celeba/198357.jpg
#   inflating: data/img_align_celeba/198358.jpg
#   inflating: data/img_align_celeba/198359.jpg
#   inflating: data/img_align_celeba/198360.jpg
#   inflating: data/img_align_celeba/198361.jpg
#   inflating: data/img_align_celeba/198362.jpg
#   inflating: data/img_align_celeba/198363.jpg
#   inflating: data/img_align_celeba/198364.jpg
#   inflating: data/img_align_celeba/198365.jpg
#   inflating: data/img_align_celeba/198366.jpg
#   inflating: data/img_align_celeba/198367.jpg
#   inflating: data/img_align_celeba/198368.jpg
#   inflating: data/img_align_celeba/198369.jpg
#   inflating: data/img_align_celeba/198370.jpg
#   inflating: data/img_align_celeba/198371.jpg
#   inflating: data/img_align_celeba/198372.jpg
#   inflating: data/img_align_celeba/198373.jpg
#   inflating: data/img_align_celeba/198374.jpg
#   inflating: data/img_align_celeba/198375.jpg
#   inflating: data/img_align_celeba/198376.jpg
#   inflating: data/img_align_celeba/198377.jpg
#   inflating: data/img_align_celeba/198378.jpg
#   inflating: data/img_align_celeba/198379.jpg
#   inflating: data/img_align_celeba/198380.jpg
#   inflating: data/img_align_celeba/198381.jpg
#   inflating: data/img_align_celeba/198382.jpg
#   inflating: data/img_align_celeba/198383.jpg
#   inflating: data/img_align_celeba/198384.jpg
#   inflating: data/img_align_celeba/198385.jpg
#   inflating: data/img_align_celeba/198386.jpg
#   inflating: data/img_align_celeba/198387.jpg
#   inflating: data/img_align_celeba/198388.jpg
#   inflating: data/img_align_celeba/198389.jpg
#   inflating: data/img_align_celeba/198390.jpg
#   inflating: data/img_align_celeba/198391.jpg
#   inflating: data/img_align_celeba/198392.jpg
#   inflating: data/img_align_celeba/198393.jpg
#   inflating: data/img_align_celeba/198394.jpg
#   inflating: data/img_align_celeba/198395.jpg
#   inflating: data/img_align_celeba/198396.jpg
#   inflating: data/img_align_celeba/198397.jpg
#   inflating: data/img_align_celeba/198398.jpg
#   inflating: data/img_align_celeba/198399.jpg
#   inflating: data/img_align_celeba/198400.jpg
#   inflating: data/img_align_celeba/198401.jpg
#   inflating: data/img_align_celeba/198402.jpg
#   inflating: data/img_align_celeba/198403.jpg
#   inflating: data/img_align_celeba/198404.jpg
#   inflating: data/img_align_celeba/198405.jpg
#   inflating: data/img_align_celeba/198406.jpg
#   inflating: data/img_align_celeba/198407.jpg
#   inflating: data/img_align_celeba/198408.jpg
#   inflating: data/img_align_celeba/198409.jpg
#   inflating: data/img_align_celeba/198410.jpg
#   inflating: data/img_align_celeba/198411.jpg
#   inflating: data/img_align_celeba/198412.jpg
#   inflating: data/img_align_celeba/198413.jpg
#   inflating: data/img_align_celeba/198414.jpg
#   inflating: data/img_align_celeba/198415.jpg
#   inflating: data/img_align_celeba/198416.jpg
#   inflating: data/img_align_celeba/198417.jpg
#   inflating: data/img_align_celeba/198418.jpg
#   inflating: data/img_align_celeba/198419.jpg
#   inflating: data/img_align_celeba/198420.jpg
#   inflating: data/img_align_celeba/198421.jpg
#   inflating: data/img_align_celeba/198422.jpg
#   inflating: data/img_align_celeba/198423.jpg
#   inflating: data/img_align_celeba/198424.jpg
#   inflating: data/img_align_celeba/198425.jpg
#   inflating: data/img_align_celeba/198426.jpg
#   inflating: data/img_align_celeba/198427.jpg
#   inflating: data/img_align_celeba/198428.jpg
#   inflating: data/img_align_celeba/198429.jpg
#   inflating: data/img_align_celeba/198430.jpg
#   inflating: data/img_align_celeba/198431.jpg
#   inflating: data/img_align_celeba/198432.jpg
#   inflating: data/img_align_celeba/198433.jpg
#   inflating: data/img_align_celeba/198434.jpg
#   inflating: data/img_align_celeba/198435.jpg
#   inflating: data/img_align_celeba/198436.jpg
#   inflating: data/img_align_celeba/198437.jpg
#   inflating: data/img_align_celeba/198438.jpg
#   inflating: data/img_align_celeba/198439.jpg
#   inflating: data/img_align_celeba/198440.jpg
#   inflating: data/img_align_celeba/198441.jpg
#   inflating: data/img_align_celeba/198442.jpg
#   inflating: data/img_align_celeba/198443.jpg
#   inflating: data/img_align_celeba/198444.jpg
#   inflating: data/img_align_celeba/198445.jpg
#   inflating: data/img_align_celeba/198446.jpg
#   inflating: data/img_align_celeba/198447.jpg
#   inflating: data/img_align_celeba/198448.jpg
#   inflating: data/img_align_celeba/198449.jpg
#   inflating: data/img_align_celeba/198450.jpg
#   inflating: data/img_align_celeba/198451.jpg
#   inflating: data/img_align_celeba/198452.jpg
#   inflating: data/img_align_celeba/198453.jpg
#   inflating: data/img_align_celeba/198454.jpg
#   inflating: data/img_align_celeba/198455.jpg
#   inflating: data/img_align_celeba/198456.jpg
#   inflating: data/img_align_celeba/198457.jpg
#   inflating: data/img_align_celeba/198458.jpg
#   inflating: data/img_align_celeba/198459.jpg
#   inflating: data/img_align_celeba/198460.jpg
#   inflating: data/img_align_celeba/198461.jpg
#   inflating: data/img_align_celeba/198462.jpg
#   inflating: data/img_align_celeba/198463.jpg
#   inflating: data/img_align_celeba/198464.jpg
#   inflating: data/img_align_celeba/198465.jpg
#   inflating: data/img_align_celeba/198466.jpg
#   inflating: data/img_align_celeba/198467.jpg
#   inflating: data/img_align_celeba/198468.jpg
#   inflating: data/img_align_celeba/198469.jpg
#   inflating: data/img_align_celeba/198470.jpg
#   inflating: data/img_align_celeba/198471.jpg
#   inflating: data/img_align_celeba/198472.jpg
#   inflating: data/img_align_celeba/198473.jpg
#   inflating: data/img_align_celeba/198474.jpg
#   inflating: data/img_align_celeba/198475.jpg
#   inflating: data/img_align_celeba/198476.jpg
#   inflating: data/img_align_celeba/198477.jpg
#   inflating: data/img_align_celeba/198478.jpg
#   inflating: data/img_align_celeba/198479.jpg
#   inflating: data/img_align_celeba/198480.jpg
#   inflating: data/img_align_celeba/198481.jpg
#   inflating: data/img_align_celeba/198482.jpg
#   inflating: data/img_align_celeba/198483.jpg
#   inflating: data/img_align_celeba/198484.jpg
#   inflating: data/img_align_celeba/198485.jpg
#   inflating: data/img_align_celeba/198486.jpg
#   inflating: data/img_align_celeba/198487.jpg
#   inflating: data/img_align_celeba/198488.jpg
#   inflating: data/img_align_celeba/198489.jpg
#   inflating: data/img_align_celeba/198490.jpg
#   inflating: data/img_align_celeba/198491.jpg
#   inflating: data/img_align_celeba/198492.jpg
#   inflating: data/img_align_celeba/198493.jpg
#   inflating: data/img_align_celeba/198494.jpg
#   inflating: data/img_align_celeba/198495.jpg
#   inflating: data/img_align_celeba/198496.jpg
#   inflating: data/img_align_celeba/198497.jpg
#   inflating: data/img_align_celeba/198498.jpg
#   inflating: data/img_align_celeba/198499.jpg
#   inflating: data/img_align_celeba/198500.jpg
#   inflating: data/img_align_celeba/198501.jpg
#   inflating: data/img_align_celeba/198502.jpg
#   inflating: data/img_align_celeba/198503.jpg
#   inflating: data/img_align_celeba/198504.jpg
#   inflating: data/img_align_celeba/198505.jpg
#   inflating: data/img_align_celeba/198506.jpg
#   inflating: data/img_align_celeba/198507.jpg
#   inflating: data/img_align_celeba/198508.jpg
#   inflating: data/img_align_celeba/198509.jpg
#   inflating: data/img_align_celeba/198510.jpg
#   inflating: data/img_align_celeba/198511.jpg
#   inflating: data/img_align_celeba/198512.jpg
#   inflating: data/img_align_celeba/198513.jpg
#   inflating: data/img_align_celeba/198514.jpg
#   inflating: data/img_align_celeba/198515.jpg
#   inflating: data/img_align_celeba/198516.jpg
#   inflating: data/img_align_celeba/198517.jpg
#   inflating: data/img_align_celeba/198518.jpg
#   inflating: data/img_align_celeba/198519.jpg
#   inflating: data/img_align_celeba/198520.jpg
#   inflating: data/img_align_celeba/198521.jpg
#   inflating: data/img_align_celeba/198522.jpg
#   inflating: data/img_align_celeba/198523.jpg
#   inflating: data/img_align_celeba/198524.jpg
#   inflating: data/img_align_celeba/198525.jpg
#   inflating: data/img_align_celeba/198526.jpg
#   inflating: data/img_align_celeba/198527.jpg
#   inflating: data/img_align_celeba/198528.jpg
#   inflating: data/img_align_celeba/198529.jpg
#   inflating: data/img_align_celeba/198530.jpg
#   inflating: data/img_align_celeba/198531.jpg
#   inflating: data/img_align_celeba/198532.jpg
#   inflating: data/img_align_celeba/198533.jpg
#   inflating: data/img_align_celeba/198534.jpg
#   inflating: data/img_align_celeba/198535.jpg
#   inflating: data/img_align_celeba/198536.jpg
#   inflating: data/img_align_celeba/198537.jpg
#   inflating: data/img_align_celeba/198538.jpg
#   inflating: data/img_align_celeba/198539.jpg
#   inflating: data/img_align_celeba/198540.jpg
#   inflating: data/img_align_celeba/198541.jpg
#   inflating: data/img_align_celeba/198542.jpg
#   inflating: data/img_align_celeba/198543.jpg
#   inflating: data/img_align_celeba/198544.jpg
#   inflating: data/img_align_celeba/198545.jpg
#   inflating: data/img_align_celeba/198546.jpg
#   inflating: data/img_align_celeba/198547.jpg
#   inflating: data/img_align_celeba/198548.jpg
#   inflating: data/img_align_celeba/198549.jpg
#   inflating: data/img_align_celeba/198550.jpg
#   inflating: data/img_align_celeba/198551.jpg
#   inflating: data/img_align_celeba/198552.jpg
#   inflating: data/img_align_celeba/198553.jpg
#   inflating: data/img_align_celeba/198554.jpg
#   inflating: data/img_align_celeba/198555.jpg
#   inflating: data/img_align_celeba/198556.jpg
#   inflating: data/img_align_celeba/198557.jpg
#   inflating: data/img_align_celeba/198558.jpg
#   inflating: data/img_align_celeba/198559.jpg
#   inflating: data/img_align_celeba/198560.jpg
#   inflating: data/img_align_celeba/198561.jpg
#   inflating: data/img_align_celeba/198562.jpg
#   inflating: data/img_align_celeba/198563.jpg
#   inflating: data/img_align_celeba/198564.jpg
#   inflating: data/img_align_celeba/198565.jpg
#   inflating: data/img_align_celeba/198566.jpg
#   inflating: data/img_align_celeba/198567.jpg
#   inflating: data/img_align_celeba/198568.jpg
#   inflating: data/img_align_celeba/198569.jpg
#   inflating: data/img_align_celeba/198570.jpg
#   inflating: data/img_align_celeba/198571.jpg
#   inflating: data/img_align_celeba/198572.jpg
#   inflating: data/img_align_celeba/198573.jpg
#   inflating: data/img_align_celeba/198574.jpg
#   inflating: data/img_align_celeba/198575.jpg
#   inflating: data/img_align_celeba/198576.jpg
#   inflating: data/img_align_celeba/198577.jpg
#   inflating: data/img_align_celeba/198578.jpg
#   inflating: data/img_align_celeba/198579.jpg
#   inflating: data/img_align_celeba/198580.jpg
#   inflating: data/img_align_celeba/198581.jpg
#   inflating: data/img_align_celeba/198582.jpg
#   inflating: data/img_align_celeba/198583.jpg
#   inflating: data/img_align_celeba/198584.jpg
#   inflating: data/img_align_celeba/198585.jpg
#   inflating: data/img_align_celeba/198586.jpg
#   inflating: data/img_align_celeba/198587.jpg
#   inflating: data/img_align_celeba/198588.jpg
#   inflating: data/img_align_celeba/198589.jpg
#   inflating: data/img_align_celeba/198590.jpg
#   inflating: data/img_align_celeba/198591.jpg
#   inflating: data/img_align_celeba/198592.jpg
#   inflating: data/img_align_celeba/198593.jpg
#   inflating: data/img_align_celeba/198594.jpg
#   inflating: data/img_align_celeba/198595.jpg
#   inflating: data/img_align_celeba/198596.jpg
#   inflating: data/img_align_celeba/198597.jpg
# ...
#   inflating: data/img_align_celeba/202267.jpg
#   inflating: data/img_align_celeba/202268.jpg
#   inflating: data/img_align_celeba/202269.jpg
#   inflating: data/img_align_celeba/202270.jpg
#   inflating: data/img_align_celeba/202271.jpg
#   inflating: data/img_align_celeba/202272.jpg
#   inflating: data/img_align_celeba/202273.jpg
#   inflating: data/img_align_celeba/202274.jpg
#   inflating: data/img_align_celeba/202275.jpg
#   inflating: data/img_align_celeba/202276.jpg
#   inflating: data/img_align_celeba/202277.jpg
#   inflating: data/img_align_celeba/202278.jpg
#   inflating: data/img_align_celeba/202279.jpg
#   inflating: data/img_align_celeba/202280.jpg
#   inflating: data/img_align_celeba/202281.jpg
#   inflating: data/img_align_celeba/202282.jpg
#   inflating: data/img_align_celeba/202283.jpg
#   inflating: data/img_align_celeba/202284.jpg
#   inflating: data/img_align_celeba/202285.jpg
#   inflating: data/img_align_celeba/202286.jpg
#   inflating: data/img_align_celeba/202287.jpg
#   inflating: data/img_align_celeba/202288.jpg
#   inflating: data/img_align_celeba/202289.jpg
#   inflating: data/img_align_celeba/202290.jpg
#   inflating: data/img_align_celeba/202291.jpg
#   inflating: data/img_align_celeba/202292.jpg
#   inflating: data/img_align_celeba/202293.jpg
#   inflating: data/img_align_celeba/202294.jpg
#   inflating: data/img_align_celeba/202295.jpg
#   inflating: data/img_align_celeba/202296.jpg
#   inflating: data/img_align_celeba/202297.jpg
#   inflating: data/img_align_celeba/202298.jpg
#   inflating: data/img_align_celeba/202299.jpg
#   inflating: data/img_align_celeba/202300.jpg
#   inflating: data/img_align_celeba/202301.jpg
#   inflating: data/img_align_celeba/202302.jpg
#   inflating: data/img_align_celeba/202303.jpg
#   inflating: data/img_align_celeba/202304.jpg
#   inflating: data/img_align_celeba/202305.jpg
#   inflating: data/img_align_celeba/202306.jpg
#   inflating: data/img_align_celeba/202307.jpg
#   inflating: data/img_align_celeba/202308.jpg
#   inflating: data/img_align_celeba/202309.jpg
#   inflating: data/img_align_celeba/202310.jpg
#   inflating: data/img_align_celeba/202311.jpg
#   inflating: data/img_align_celeba/202312.jpg
#   inflating: data/img_align_celeba/202313.jpg
#   inflating: data/img_align_celeba/202314.jpg
#   inflating: data/img_align_celeba/202315.jpg
#   inflating: data/img_align_celeba/202316.jpg
#   inflating: data/img_align_celeba/202317.jpg
#   inflating: data/img_align_celeba/202318.jpg
#   inflating: data/img_align_celeba/202319.jpg
#   inflating: data/img_align_celeba/202320.jpg
#   inflating: data/img_align_celeba/202321.jpg
#   inflating: data/img_align_celeba/202322.jpg
#   inflating: data/img_align_celeba/202323.jpg
#   inflating: data/img_align_celeba/202324.jpg
#   inflating: data/img_align_celeba/202325.jpg
#   inflating: data/img_align_celeba/202326.jpg
#   inflating: data/img_align_celeba/202327.jpg
#   inflating: data/img_align_celeba/202328.jpg
#   inflating: data/img_align_celeba/202329.jpg
#   inflating: data/img_align_celeba/202330.jpg
#   inflating: data/img_align_celeba/202331.jpg
#   inflating: data/img_align_celeba/202332.jpg
#   inflating: data/img_align_celeba/202333.jpg
#   inflating: data/img_align_celeba/202334.jpg
#   inflating: data/img_align_celeba/202335.jpg
#   inflating: data/img_align_celeba/202336.jpg
#   inflating: data/img_align_celeba/202337.jpg
#   inflating: data/img_align_celeba/202338.jpg
#   inflating: data/img_align_celeba/202339.jpg
#   inflating: data/img_align_celeba/202340.jpg
#   inflating: data/img_align_celeba/202341.jpg
#   inflating: data/img_align_celeba/202342.jpg
#   inflating: data/img_align_celeba/202343.jpg
#   inflating: data/img_align_celeba/202344.jpg
#   inflating: data/img_align_celeba/202345.jpg
#   inflating: data/img_align_celeba/202346.jpg
#   inflating: data/img_align_celeba/202347.jpg
#   inflating: data/img_align_celeba/202348.jpg
#   inflating: data/img_align_celeba/202349.jpg
#   inflating: data/img_align_celeba/202350.jpg
#   inflating: data/img_align_celeba/202351.jpg
#   inflating: data/img_align_celeba/202352.jpg
#   inflating: data/img_align_celeba/202353.jpg
#   inflating: data/img_align_celeba/202354.jpg
#   inflating: data/img_align_celeba/202355.jpg
#   inflating: data/img_align_celeba/202356.jpg
#   inflating: data/img_align_celeba/202357.jpg
#   inflating: data/img_align_celeba/202358.jpg
#   inflating: data/img_align_celeba/202359.jpg
#   inflating: data/img_align_celeba/202360.jpg
#   inflating: data/img_align_celeba/202361.jpg
#   inflating: data/img_align_celeba/202362.jpg
#   inflating: data/img_align_celeba/202363.jpg
#   inflating: data/img_align_celeba/202364.jpg
#   inflating: data/img_align_celeba/202365.jpg
#   inflating: data/img_align_celeba/202366.jpg
#   inflating: data/img_align_celeba/202367.jpg
#   inflating: data/img_align_celeba/202368.jpg
#   inflating: data/img_align_celeba/202369.jpg
#   inflating: data/img_align_celeba/202370.jpg
#   inflating: data/img_align_celeba/202371.jpg
#   inflating: data/img_align_celeba/202372.jpg
#   inflating: data/img_align_celeba/202373.jpg
#   inflating: data/img_align_celeba/202374.jpg
#   inflating: data/img_align_celeba/202375.jpg
#   inflating: data/img_align_celeba/202376.jpg
#   inflating: data/img_align_celeba/202377.jpg
#   inflating: data/img_align_celeba/202378.jpg
#   inflating: data/img_align_celeba/202379.jpg
#   inflating: data/img_align_celeba/202380.jpg
#   inflating: data/img_align_celeba/202381.jpg
#   inflating: data/img_align_celeba/202382.jpg
#   inflating: data/img_align_celeba/202383.jpg
#   inflating: data/img_align_celeba/202384.jpg
#   inflating: data/img_align_celeba/202385.jpg
#   inflating: data/img_align_celeba/202386.jpg
#   inflating: data/img_align_celeba/202387.jpg
#   inflating: data/img_align_celeba/202388.jpg
#   inflating: data/img_align_celeba/202389.jpg
#   inflating: data/img_align_celeba/202390.jpg
#   inflating: data/img_align_celeba/202391.jpg
#   inflating: data/img_align_celeba/202392.jpg
#   inflating: data/img_align_celeba/202393.jpg
#   inflating: data/img_align_celeba/202394.jpg
#   inflating: data/img_align_celeba/202395.jpg
#   inflating: data/img_align_celeba/202396.jpg
#   inflating: data/img_align_celeba/202397.jpg
#   inflating: data/img_align_celeba/202398.jpg
#   inflating: data/img_align_celeba/202399.jpg
#   inflating: data/img_align_celeba/202400.jpg
#   inflating: data/img_align_celeba/202401.jpg
#   inflating: data/img_align_celeba/202402.jpg
#   inflating: data/img_align_celeba/202403.jpg
#   inflating: data/img_align_celeba/202404.jpg
#   inflating: data/img_align_celeba/202405.jpg
#   inflating: data/img_align_celeba/202406.jpg
#   inflating: data/img_align_celeba/202407.jpg
#   inflating: data/img_align_celeba/202408.jpg
#   inflating: data/img_align_celeba/202409.jpg
#   inflating: data/img_align_celeba/202410.jpg
#   inflating: data/img_align_celeba/202411.jpg
#   inflating: data/img_align_celeba/202412.jpg
#   inflating: data/img_align_celeba/202413.jpg
#   inflating: data/img_align_celeba/202414.jpg
#   inflating: data/img_align_celeba/202415.jpg
#   inflating: data/img_align_celeba/202416.jpg
#   inflating: data/img_align_celeba/202417.jpg
#   inflating: data/img_align_celeba/202418.jpg
#   inflating: data/img_align_celeba/202419.jpg
#   inflating: data/img_align_celeba/202420.jpg
#   inflating: data/img_align_celeba/202421.jpg
#   inflating: data/img_align_celeba/202422.jpg
#   inflating: data/img_align_celeba/202423.jpg
#   inflating: data/img_align_celeba/202424.jpg
#   inflating: data/img_align_celeba/202425.jpg
#   inflating: data/img_align_celeba/202426.jpg
#   inflating: data/img_align_celeba/202427.jpg
#   inflating: data/img_align_celeba/202428.jpg
#   inflating: data/img_align_celeba/202429.jpg
#   inflating: data/img_align_celeba/202430.jpg
#   inflating: data/img_align_celeba/202431.jpg
#   inflating: data/img_align_celeba/202432.jpg
#   inflating: data/img_align_celeba/202433.jpg
#   inflating: data/img_align_celeba/202434.jpg
#   inflating: data/img_align_celeba/202435.jpg
#   inflating: data/img_align_celeba/202436.jpg
#   inflating: data/img_align_celeba/202437.jpg
#   inflating: data/img_align_celeba/202438.jpg
#   inflating: data/img_align_celeba/202439.jpg
#   inflating: data/img_align_celeba/202440.jpg
#   inflating: data/img_align_celeba/202441.jpg
#   inflating: data/img_align_celeba/202442.jpg
#   inflating: data/img_align_celeba/202443.jpg
#   inflating: data/img_align_celeba/202444.jpg
#   inflating: data/img_align_celeba/202445.jpg
#   inflating: data/img_align_celeba/202446.jpg
#   inflating: data/img_align_celeba/202447.jpg
#   inflating: data/img_align_celeba/202448.jpg
#   inflating: data/img_align_celeba/202449.jpg
#   inflating: data/img_align_celeba/202450.jpg
#   inflating: data/img_align_celeba/202451.jpg
#   inflating: data/img_align_celeba/202452.jpg
#   inflating: data/img_align_celeba/202453.jpg
#   inflating: data/img_align_celeba/202454.jpg
#   inflating: data/img_align_celeba/202455.jpg
#   inflating: data/img_align_celeba/202456.jpg
#   inflating: data/img_align_celeba/202457.jpg
#   inflating: data/img_align_celeba/202458.jpg
#   inflating: data/img_align_celeba/202459.jpg
#   inflating: data/img_align_celeba/202460.jpg
#   inflating: data/img_align_celeba/202461.jpg
#   inflating: data/img_align_celeba/202462.jpg
#   inflating: data/img_align_celeba/202463.jpg
#   inflating: data/img_align_celeba/202464.jpg
#   inflating: data/img_align_celeba/202465.jpg
#   inflating: data/img_align_celeba/202466.jpg
#   inflating: data/img_align_celeba/202467.jpg
#   inflating: data/img_align_celeba/202468.jpg
#   inflating: data/img_align_celeba/202469.jpg
#   inflating: data/img_align_celeba/202470.jpg
#   inflating: data/img_align_celeba/202471.jpg
#   inflating: data/img_align_celeba/202472.jpg
#   inflating: data/img_align_celeba/202473.jpg
#   inflating: data/img_align_celeba/202474.jpg
#   inflating: data/img_align_celeba/202475.jpg
#   inflating: data/img_align_celeba/202476.jpg
#   inflating: data/img_align_celeba/202477.jpg
#   inflating: data/img_align_celeba/202478.jpg
#   inflating: data/img_align_celeba/202479.jpg
#   inflating: data/img_align_celeba/202480.jpg
#   inflating: data/img_align_celeba/202481.jpg
#   inflating: data/img_align_celeba/202482.jpg
#   inflating: data/img_align_celeba/202483.jpg
#   inflating: data/img_align_celeba/202484.jpg
#   inflating: data/img_align_celeba/202485.jpg
#   inflating: data/img_align_celeba/202486.jpg
#   inflating: data/img_align_celeba/202487.jpg
#   inflating: data/img_align_celeba/202488.jpg
#   inflating: data/img_align_celeba/202489.jpg
#   inflating: data/img_align_celeba/202490.jpg
#   inflating: data/img_align_celeba/202491.jpg
#   inflating: data/img_align_celeba/202492.jpg
#   inflating: data/img_align_celeba/202493.jpg
#   inflating: data/img_align_celeba/202494.jpg
#   inflating: data/img_align_celeba/202495.jpg
#   inflating: data/img_align_celeba/202496.jpg
#   inflating: data/img_align_celeba/202497.jpg
#   inflating: data/img_align_celeba/202498.jpg
#   inflating: data/img_align_celeba/202499.jpg
#   inflating: data/img_align_celeba/202500.jpg
#   inflating: data/img_align_celeba/202501.jpg
#   inflating: data/img_align_celeba/202502.jpg
#   inflating: data/img_align_celeba/202503.jpg
#   inflating: data/img_align_celeba/202504.jpg
#   inflating: data/img_align_celeba/202505.jpg
#   inflating: data/img_align_celeba/202506.jpg
#   inflating: data/img_align_celeba/202507.jpg
#   inflating: data/img_align_celeba/202508.jpg
#   inflating: data/img_align_celeba/202509.jpg
#   inflating: data/img_align_celeba/202510.jpg
#   inflating: data/img_align_celeba/202511.jpg
#   inflating: data/img_align_celeba/202512.jpg
#   inflating: data/img_align_celeba/202513.jpg
#   inflating: data/img_align_celeba/202514.jpg
#   inflating: data/img_align_celeba/202515.jpg
#   inflating: data/img_align_celeba/202516.jpg
#   inflating: data/img_align_celeba/202517.jpg
#   inflating: data/img_align_celeba/202518.jpg
#   inflating: data/img_align_celeba/202519.jpg
#   inflating: data/img_align_celeba/202520.jpg
#   inflating: data/img_align_celeba/202521.jpg
#   inflating: data/img_align_celeba/202522.jpg
#   inflating: data/img_align_celeba/202523.jpg
#   inflating: data/img_align_celeba/202524.jpg
#   inflating: data/img_align_celeba/202525.jpg
#   inflating: data/img_align_celeba/202526.jpg
#   inflating: data/img_align_celeba/202527.jpg
#   inflating: data/img_align_celeba/202528.jpg
#   inflating: data/img_align_celeba/202529.jpg
#   inflating: data/img_align_celeba/202530.jpg
#   inflating: data/img_align_celeba/202531.jpg
#   inflating: data/img_align_celeba/202532.jpg
#   inflating: data/img_align_celeba/202533.jpg
#   inflating: data/img_align_celeba/202534.jpg
#   inflating: data/img_align_celeba/202535.jpg
#   inflating: data/img_align_celeba/202536.jpg
#   inflating: data/img_align_celeba/202537.jpg
#   inflating: data/img_align_celeba/202538.jpg
#   inflating: data/img_align_celeba/202539.jpg
#   inflating: data/img_align_celeba/202540.jpg
#   inflating: data/img_align_celeba/202541.jpg
#   inflating: data/img_align_celeba/202542.jpg
#   inflating: data/img_align_celeba/202543.jpg
#   inflating: data/img_align_celeba/202544.jpg
#   inflating: data/img_align_celeba/202545.jpg
#   inflating: data/img_align_celeba/202546.jpg
#   inflating: data/img_align_celeba/202547.jpg
#   inflating: data/img_align_celeba/202548.jpg
#   inflating: data/img_align_celeba/202549.jpg
#   inflating: data/img_align_celeba/202550.jpg
#   inflating: data/img_align_celeba/202551.jpg
#   inflating: data/img_align_celeba/202552.jpg
#   inflating: data/img_align_celeba/202553.jpg
#   inflating: data/img_align_celeba/202554.jpg
#   inflating: data/img_align_celeba/202555.jpg
#   inflating: data/img_align_celeba/202556.jpg
#   inflating: data/img_align_celeba/202557.jpg
#   inflating: data/img_align_celeba/202558.jpg
#   inflating: data/img_align_celeba/202559.jpg
#   inflating: data/img_align_celeba/202560.jpg
#   inflating: data/img_align_celeba/202561.jpg
#   inflating: data/img_align_celeba/202562.jpg
#   inflating: data/img_align_celeba/202563.jpg
#   inflating: data/img_align_celeba/202564.jpg
#   inflating: data/img_align_celeba/202565.jpg
#   inflating: data/img_align_celeba/202566.jpg
#   inflating: data/img_align_celeba/202567.jpg
#   inflating: data/img_align_celeba/202568.jpg
#   inflating: data/img_align_celeba/202569.jpg
#   inflating: data/img_align_celeba/202570.jpg
#   inflating: data/img_align_celeba/202571.jpg
#   inflating: data/img_align_celeba/202572.jpg
#   inflating: data/img_align_celeba/202573.jpg
#   inflating: data/img_align_celeba/202574.jpg
#   inflating: data/img_align_celeba/202575.jpg
#   inflating: data/img_align_celeba/202576.jpg
#   inflating: data/img_align_celeba/202577.jpg
#   inflating: data/img_align_celeba/202578.jpg
#   inflating: data/img_align_celeba/202579.jpg
#   inflating: data/img_align_celeba/202580.jpg
#   inflating: data/img_align_celeba/202581.jpg
#   inflating: data/img_align_celeba/202582.jpg
#   inflating: data/img_align_celeba/202583.jpg
#   inflating: data/img_align_celeba/202584.jpg
#   inflating: data/img_align_celeba/202585.jpg
#   inflating: data/img_align_celeba/202586.jpg
#   inflating: data/img_align_celeba/202587.jpg
#   inflating: data/img_align_celeba/202588.jpg
#   inflating: data/img_align_celeba/202589.jpg
#   inflating: data/img_align_celeba/202590.jpg
#   inflating: data/img_align_celeba/202591.jpg
#   inflating: data/img_align_celeba/202592.jpg
#   inflating: data/img_align_celeba/202593.jpg
#   inflating: data/img_align_celeba/202594.jpg
#   inflating: data/img_align_celeba/202595.jpg
#   inflating: data/img_align_celeba/202596.jpg
#   inflating: data/img_align_celeba/202597.jpg
#   inflating: data/img_align_celeba/202598.jpg
#   inflating: data/img_align_celeba/202599.jpg

# %% [markdown]
# Cela produit un répertoire data à la racine du repertoire temporaire de votre Google Colab. Ce repertoire contient un sous-repertoire img_align_celeba contenant une liste de 202599 fichiers jpg correspondant à des photos de visages de célébrités (attention ce repertoire est temporaire, tout ce qui n'est pas dans un drive est effacé à la fin de la session).

# %%
import numpy as np
try:
    import torch
except:
    # !pip3 install torch==1.2.0+cu92 torchvision==0.4.0+cu92 -f https://download.pytorch.org/whl/torch_stable.html
    import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.utils.data
import torchvision.datasets as dset
import torchvision.utils as vutils
import torch.backends.cudnn as cudnn

# %% [markdown]
# Le code ci-dessous permet de déclarer la manière de charger les données.
#
# Lorsque des données sont demandées (pour la construction d'un nouveau batch par exemple), une série de transformations est appliquée sur les images, selon la composition de transformateurs déclarée pour le chargement:
# *    redimentionnement des images en 64 par 64
# *    recadrage au centre (qui ne fait rien ici car image déjà dans la taille du cadre mais si utile pour d'autres paramètres)
# *    conversion en tenseur pytorch
# *    normalisation des valeurs RGB selon une moyenne de 0.5 et un ecart-type de 0.5.

# %%
image_size = 64
dataset = dset.ImageFolder(root="data",
                           transform=transforms.Compose([
                               transforms.Resize(image_size),
                               transforms.CenterCrop(image_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

# %%
print(dataset)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 102599
#     Root location: data
#     StandardTransform
# Transform: Compose(
#                Resize(size=64, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(64, 64))
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %%
print(dataset)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 202599
#     Root location: archive/img_align_celeba
#     StandardTransform
# Transform: Compose(
#                Resize(size=64, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(64, 64))
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %% [markdown]
# Le code ci-dessous permet de déclarer la manière de charger les images et en affiche un échantillon.

# %%
import matplotlib.pyplot as plt
import os



seed=0
torch.manual_seed(seed)
np.random.seed(seed)
device=0
if device>=0 and torch.cuda.is_available():
  cudnn.benchmark = True
  torch.cuda.device(device)
  torch.cuda.manual_seed(seed)
else: 
  device=-1

batch_size = 128
workers = 2

dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                         shuffle=True, num_workers=workers)

# Affichage de quelques images
real_batch = next(iter(dataloader)) #real_batch est une liste de 2 tenseurs où le 1er correspond aux images, les second correspond aux labels (ici 0 partout)

plt.figure(figsize=(15,15))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=1, normalize=True).cpu(),(1,2,0)))
os.makedirs("drive/My Drive/genFaces",exist_ok=True)
plt.savefig("drive/My Drive/genFaces/train.png" ) # Pour sauvegarder l'image sur votre Google Drive

# %% [markdown]
# Le réseau $D$ est un empilement de couches de convolution 2D avec batchNorm2D et activations RELU:

# %%
nc = 3 # Nombre de canaux de l'entrée
ndf = 64 # Facteur du nombre de canaux de sortie des différentes couches de convolution


# Initialisation recommandee pour netG et netD dans DCGAN
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.main = nn.Sequential(
            # input is (nc) x 64 x 64
            nn.Conv2d(nc, ndf, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf) x 32 x 32
            nn.Conv2d(ndf, ndf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 2),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*2) x 16 x 16
            nn.Conv2d(ndf * 2, ndf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*4) x 8 x 8
            nn.Conv2d(ndf * 4, ndf * 8, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ndf * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # state size. (ndf*8) x 4 x 4
            nn.Conv2d(ndf * 8, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input)


netD = Discriminator().to(device)
netD.apply(weights_init)
print(netD)
# Out:
# Discriminator(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (12): Sigmoid()
#   )
# )

# %%
nz=100  #Taille du vecteur z donné en entrée du générateur
ngf = 64 # Facteur du nombre de canaux de sortie des différentes couches de deconvolution

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            # input is Z, going into a convolution
            nn.ConvTranspose2d( nz, ngf * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(ngf * 8),
            nn.ReLU(True),
            # state size. (ngf*8) x 4 x 4
            nn.ConvTranspose2d(ngf * 8, ngf * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 4),
            nn.ReLU(True),
            # state size. (ngf*4) x 8 x 8
            nn.ConvTranspose2d( ngf * 4, ngf * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf * 2),
            nn.ReLU(True),
            # state size. (ngf*2) x 16 x 16
            nn.ConvTranspose2d( ngf * 2, ngf, 4, 2, 1, bias=False),
            nn.BatchNorm2d(ngf),
            nn.ReLU(True),
            # state size. (ngf) x 32 x 32
            nn.ConvTranspose2d( ngf, nc, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size. (nc) x 64 x 64
        )

    def forward(self, input):
        return self.main(input)
netG = Generator().to(device)
netG.apply(weights_init)
print(netG)
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %% [markdown]
# Donner la procédure d'entraînement de ces deux réseaux. L'optimisation se fera ADAM selon les deux coûts adverses du discriminateur et du générateur. Pour chaque nouveau batch d'images, on alterne les deux mises à jour suivantes, selon un batch de vecteurs $z$ tirés aléatoirement selon une loi normale centrée réduite (un nouveau batch de $z$ à chaque itération):
#
# 1.   Un pas de gradient sur les paramètres du réseau D pour maximiser:  $log(D(x)) + log(1 - D(G(z)))$
# 2.   Un pas de gradient sur les paramètres du réseau G pour maximiser:  $log(D(G(z)))$
#
#
# Afin de suivre l'évolution de l'apprentissage, on pourra logguer l'erreur du discriminateur relevée en 1, l'erreur du générateur relevée en 2, la moyenne des sorties du discriminateur sur les images réelles et la moyenne des sorties du discriminateur sur les images générées.
#
# À la fin de chaque époque (i.e., lorsque l'on a itéré sur tous les batchs du DataLoader), on pourra enregistrer les images générées à partir d'un batch de vecteurs $z$ fixe dans le Google Drive pour observer l'évolution des capacités du générateur.

# %%
from tqdm import tqdm
import logging
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

i = 0
eps = 1e-20

nz=100
optimG = torch.optim.Adam(netG.parameters(),lr=0.001)
optimD = torch.optim.Adam(netD.parameters(),lr=0.0005)

# %%
from tqdm import tqdm
nb_epoche = 5

for epoche in tqdm(range(nb_epoche)):
    for x,y in dataloader :
        batchsize, c, w ,h = x.shape
        z = torch.randn(batchsize,nz,1,1)
        
        lossD = -(torch.log(netD(x.to(device))+eps) + torch.log(1-netD(netG(z.to(device)))+eps)).mean()
        optimD.zero_grad()
        lossD.backward()
        optimD.step()
        
        lossG = -torch.log(netD(netG(z.to(device)))+eps).mean()
        optimG.zero_grad()
        lossG.backward()
        optimG.step()
# Out:
# 100%|██████████| 5/5 [29:25<00:00, 353.10s/it]

# %% [markdown]
# Le code ci-dessous applique votre réseau à un batch de $z$ aléatoires et affiche les images générées (et enregistre dans fake.png).

# %%
noise = torch.randn(64, nz, 1, 1, device=device)
with torch.no_grad():
  netG.eval()
  fake = netG(noise).detach().cpu()
img=vutils.make_grid(fake, padding=2, normalize=True)
img_list=[]
img_list.append(img)
plt.figure(figsize=(15,15))
plt.axis("off")
plt.title("Fake Images")
plt.imshow(np.transpose(img.cpu(),(1,2,0)))
plt.savefig( "fake.png" )

# %% [markdown]
# Le générateur du papier original DCGAN possède en fait l'architecture suivante:
#
# ![Generator](https://pytorch.org/tutorials/_images/dcgan_generator.png)
#
# Comme le réseau $G$ définit plus haut, il correspond à un empilement de couches de convolutions transposées (appelée dans certains papiers couches de déconvolution). Contrairement aux convolutions classiques qui mènent à une réduction de la taille des sorties, les convolutions transposées agrandissent les cartes de caractéristiques considérées (feature maps). C'est particulièrement adapté pour de la génération d'images à partir d'un code de petite taille (ici $z$).
#
#  Pour comprendre comment fonctionne la convolution transposée, voici un exemple simple avec une entrée 2 x 2 et un noyau 2 x 2. Chaque élément de l'entrée (4 éléments) est multiplié par le noyau et le résultat est ajouté à la sorte de taille 3 x 3:
#
# ![BasicTransposeConv2D](http://d2l.ai/_images/trans-conv.svg)
#
# Et voici deux animations pour se représenter l'opération d'une manière plus générale. A gauche on utilise un stride de 1, à droite un stride de 2:
#
# <p align="center">
# <img src="https://i.stack.imgur.com/YyCu2.gif">
# <img src="https://i.stack.imgur.com/f2RiP.gif">
# </p>
#
#
# Suivant la doc Pytorch de torch.nn.ConvTranspose2d, la hauteur $H_{out}$ et la largeur $W_{out}$ des cartes de sortie du ConvTranspose2d peuvent se calculer de la manière suivante:
#
# $H_{out}$=($H_{in}$−1)×stride−2×padding+dilation×(kernel_size−1)+output_padding+1
#
# $W_{out}$=($W_{in}$−1)×stride−2×padding+dilation×(kernel_size−1)+output_padding+1
#
#
# Proposer un nouveau réseau $G$ qui respecte l'architecture du schéma du papier DCGAN et comparer les résultats. On gardera le paramètre de dilation à sa valeur de 1 par défaut mais il est possible de moduler les valeurs de padding et output_padding pour obtenir des sorties de la taille désirée.

# %% [markdown]
# Bonus: Réaliser le même genre d'apprentissage sur le corpus Mnist (Dataloader existant dans torch pour télécharger et charger le corpus)
